# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
z = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2.2/X_reduced_408 (1).csv', delimiter=';')

phi = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2.2/X_loadings_408 (1).csv', delimiter=';')

#восстановление признаков: веторное произведение вектора счетов и транспонированного вектора весов
p = np.dot(z, phi.T)

import matplotlib.pyplot as plt
plt.matshow(p)

plt.show()
